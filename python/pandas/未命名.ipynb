# %%
import sys
import glob

import pandas as pd
import os

columns = ['route_id', 'length', 's_tag.name', 'e_tag.name', 'jct_count',
        'adcode', 'region', 'proname', 'lane', 'cond', 'light', 'eye', 'rev', 'adj', 'signboard', 'total', 'link_ids']
path = '/Users/andyzhuang/tmp/result_china_2020q2_trial/2020041601/sample_highway.csv'
df = pd.read_csv(path, delimiter="\t", header=None, names=columns)

# %%
df
# Out:
#             route_id  length s_tag.name e_tag.name  jct_count  adcode region  \
# 0    1587095194062_1   27298   IN_FIRST   OUT_LAST          0  429005     华中
# 1    1587095194062_2   23570   IN_FIRST   OUT_LAST          0  511703     西南
# 2    1587095194062_3   30321   IN_FIRST   OUT_LAST          0  370406     华北
# 3    1587095194062_4   30101   IN_FIRST   OUT_LAST          0  500117     西南
# 4    1587095194062_5   28844   IN_FIRST   OUT_LAST          1  440607     华南
# 5    1587095194062_6   25752   IN_FIRST   OUT_LAST          1  370523     华北
# 6    1587095194062_7   35440   IN_FIRST   OUT_LAST          0  340828     华中
# 7    1587095194062_8   53964   IN_FIRST   OUT_LAST          2  341103     华中
# 8    1587095194062_9   22107   IN_FIRST   OUT_LAST          0  230602     东北
# 9   1587095194062_10   22185   IN_FIRST   OUT_LAST          0  220104     东北
# 10  1587095194062_11   28077   IN_FIRST   OUT_LAST          0  341621     华中
# ...

# %%
print('总数')
for key in ['length',  'jct_count', 'lane', 'cond', 'light', 'eye', 'rev', 'adj', 'signboard', 'total']:
#     print(key, '-----------------------------')
    print(key, ' ', df[key].sum())
    
print('route 总数', df['route_id'].count())
print('长度分布\n', df['length'].describe())
# Out:
# 总数
# length   1428578
# jct_count   24
# lane   194
# cond   11
# light   5
# eye   1176
# rev   0
# adj   129
# signboard   292
# total   1807
# route 总数 44
# 长度分布
#  count       44.000000
# mean     32467.681818
# std      11734.971713
# min      21033.000000
# 25%      25114.250000
# 50%      27687.500000
# 75%      36098.500000
# max      66449.000000
# Name: length, dtype: float64
